# %% [markdown]
# # Sync Link
# ### Part 2: Cleaning
#
# All the data is gathered so it's time to clean! First, I'm going to create a feautre that gauges accuracy. Since I was pulling for multiple sources, I wanted to make sure the results actually line up. Once I've verified that, I can get rid of duplicate columns like title, artist, release year, etc. and reorganize the columns.

# %%
import pandas as pd
import numpy as np
import regex as re
import requests

# %%
pt1 = pd.read_csv('./data/sync_spotify_final_1.csv')

# %%
pt2 = pd.read_csv('./data/sync_spotify_final_2.csv')

# %%
sync = pd.concat([pt1, pt2], axis = 0)

# %%
sync.duplicated().sum()
# Out:
# 0

# %%
sync = sync.drop(columns = ['index', 'level_0'])

# %%
sync.reset_index(inplace = True)

# %%
sync.shape
# Out:
# (10845, 41)

# %% [markdown]
# Imputing Data:
# Since this information is all easily found online, I'm going to save a few rows by manually reseraching and adding the info in.

# %% [markdown]
# Songs that have no lyric url are all Traditional meaning they are in the public domain and the *publishing* does not require clearance.

# %%
sync[sync['lyric_url'].isna()].fillna(0, inplace = True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
sync.dropna(inplace = True)

# %% [markdown]
# #### Step 1: Assessing Accuracy
# This dataset was built by using 4 different sources. To make sure they match, I'm going to create a function that scores the accuracy of each observation by making sure the title/artist from all four sources are the same and the years from the original set matches Deezer.

# %% [markdown]
# First, I'll need to reformat the title/artist from the sources to match the original (all lowercase with a dash inbetween).

# %%
#Deezer
sync['deezer_title_artist'] = sync['d_song'].str.lower().str.strip() + ' - ' + sync['d_artist'].str.lower().str.strip()

# %%
#Spotify
sync['spotify_title_artist'] = sync['s_track'].str.lower().str.strip() + ' - ' + sync['s_artist'].str.lower().str.strip()

# %%
#Lyric Freak has to be cleaned first
sync['l_title'] = sync['l_title'].apply(lambda x: re.sub('\\n', ' ', x))

# %%
def clean_up(song):
    song = song.replace('About', '').replace('Lyrics', '').replace('lyrics', '')
    try:
        song = song.split('–')[1]
    except:
        pass
    song = song.strip()
    return song

# %%
clean_up('Tones And I – Dance Monkey Lyrics')
# Out:
# 'Dance Monkey'

# %%
sync['l_title'] = sync['l_title'].apply(clean_up)

# %%
sync['l_title']
# Out:
# 0           Tennessee Whiskey
# 1                Dance Monkey
# 2              Sweet Caroline
# 3           Someone You Loved
# 6                       Creep
#                  ...
# 10840                       0
# 10841           Frank Sinatra
# 10842           Beautiful War
# 10843          Midnight Blues
# 10844    Smokin' And Drinkin'
# Name: l_title, Length: 10817, dtype: object

# %%
sync.isna().sum();

# %%
sync.tail()
# Out:
#        index                          title           artist  year  explicit  \
# 10840   4118                  Fixing A Hole      The Beatles  1967         0
# 10841   4119  It Came Upon a Midnight Clear    Frank Sinatra  1948         0
# 10842   4120                  Beautiful War    Kings of Leon  2013         0
# 10843   4121                 Midnight Blues       Gary Moore  1990         0
# 10844   4122           Smokin' and Drinkin'  Miranda Lambert  2014         0
#
#                                  styles languages  \
# 10840                              Rock   English
# 10841  Christmas,Christian,Traditionnal   English
# 10842                  Alternative,Rock   English
# 10843                        Blues,Rock   English
# 10844             Pop,Country,Soft rock   English
#
#                                         title_artist  synced       d_id  ...  \
# 10840                    fixing a hole - the beatles       0  116348678  ...
# 10841  it came upon a midnight clear - frank sinatra       0  115007404  ...
# 10842                  beautiful war - kings of leon       0   70584821  ...
# 10843                    midnight blues - gary moore       0    3133096  ...
# 10844         smokin' and drinkin' - miranda lambert       0   78383556  ...
#
#       s_speech s_acoustic  s_inst s_live  s_valence s_tempo  s_duration  \
# 10840   0.0356      0.706  0.0334  0.129      0.259  70.828    172133.0
# 10841   0.0356      0.706  0.0334  0.129      0.259  70.828    172133.0
# 10842   0.0356      0.706  0.0334  0.129      0.259  70.828    172133.0
# 10843   0.0356      0.706  0.0334  0.129      0.259  70.828    172133.0
# 10844   0.0356      0.706  0.0334  0.129      0.259  70.828    172133.0
#
#       s_time_sig                                deezer_title_artist  \
# 10840        4.0      fixing a hole (remastered 2009) - the beatles
# 10841        4.0        it came upon a midnight clear - bing crosby
# 10842        4.0                      beautiful war - kings of leon
# 10843        4.0                        midnight blues - gary moore
# 10844        4.0  smokin' and drinkin' (feat. little big town) -...
#
#                                     spotify_title_artist
# 10840      fixing a hole - remastered 2009 - the beatles
# 10841      it came upon a midnight clear - frank sinatra
# 10842                      beautiful war - kings of leon
# 10843                        midnight blues - gary moore
# 10844  smokin' and drinkin' (feat. little big town) -...
#
# [5 rows x 43 columns]

# %%
sync['l_title_artist'] = sync['l_title'].str.lower().str.strip() + ' - ' + sync['l_artist'].str.lower().str.strip()

# %%
def get_year(string):
    return string[0:4]

# %%
sync['d_year'] = sync['d_release'].apply(get_year)

# %%
sync.head(1).T
# Out:
#                                                                       0
# index                                                                 0
# title                                                 Tennessee Whiskey
# artist                                                  Chris Stapleton
# year                                                               2015
# explicit                                                              0
# styles                                               Blues,Rock,Country
# languages                                                       English
# title_artist                        tennessee whiskey - chris stapleton
# synced                                                                1
# d_id                                                           98975170
# d_song                                                Tennessee Whiskey
# d_isrc                                                     USUM71418088
# d_release                                                    2015-05-04
# d_explicit                                                        False
# d_bpm                                                               152
# d_artist                                                Chris Stapleton
# d_album_id                                                     10127538
# d_album                                                       Traveller
# d_art                 https://cdns-images.dzcdn.net/images/cover/1dd...
# lyric_url             /c/chris+stapleton/tennessee+whiskey_21104107....
# l_title                                               Tennessee Whiskey
# l_artist                                                Chris Stapleton
# l_album               \n                            from album:\n   ...
# l_writer                  Songwriters: Linda H Bartholomew, Dean Dillon
# l_pub                 \n                    Tennessee Whiskey lyrics...
# s_artist                                                Chris Stapleton
# s_track                                               Tennessee Whiskey
# s_uri                                            3fqwjXwUGN6vbzIwvyFMhx
# s_dance                                                           0.392
# s_energy                                                           0.37
# s_key                                                                 9
# s_loudness                                                      -10.888
# s_mode                                                                1
# s_speech                                                         0.0298
# s_acoustic                                                        0.205
# s_inst                                                           0.0096
# s_live                                                           0.0821
# s_valence                                                         0.512
# s_tempo                                                          48.718
# s_duration                                                       293293
# s_time_sig                                                            4
# deezer_title_artist                 tennessee whiskey - chris stapleton
# spotify_title_artist                tennessee whiskey - chris stapleton
# l_title_artist                      tennessee whiskey - chris stapleton
# d_year                                                             2015

# %%
sync.reset_index(inplace = True)

# %%
sample = sync.head()

# %%
sample['score'] = 0
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_score(df):
    for i in range(len(df)):
        score = 0
        if df.loc[i, 'title_artist'] == df.loc[i, 'deezer_title_artist'] :
            score += 1
        elif df.loc[i, 'title_artist'] == df.loc[i, 'spotify_title_artist']:
            score +=1
        elif df.loc[i, 'title_artist']  == df.loc[i, 'l_title_artist']:
            score += 1
        else:
            score = score
    df.loc[i, 'score'] = score
    return df

# %%
sample
# Out:
#    level_0  index              title           artist  year  explicit  \
# 0        0      0  Tennessee Whiskey  Chris Stapleton  2015         0
# 1        1      1       Dance Monkey      Tones and I  2019         0
# 2        2      2     Sweet Caroline     Neil Diamond  1969         0
# 3        3      3  Someone You Loved    Lewis Capaldi  2018         0
# 4        6      6              Creep        Radiohead  1992         1
#
#                styles languages                         title_artist  synced  \
# 0  Blues,Rock,Country   English  tennessee whiskey - chris stapleton       1
# 1                 Pop   English           dance monkey - tones and i       1
# 2                 Pop   English        sweet caroline - neil diamond       1
# 3                 Pop   English    someone you loved - lewis capaldi       1
# 4    Rock,Alternative   English                    creep - radiohead       1
#
#    ...  s_live s_valence  s_tempo s_duration s_time_sig  \
# 0  ...  0.0821     0.512   48.718   293293.0        4.0
# 1  ...  0.1490     0.513   98.027   209438.0        4.0
# 2  ...  0.2370     0.578   63.050   203573.0        4.0
# 3  ...  0.1050     0.446  109.891   182161.0        4.0
# 4  ...  0.1290     0.104   91.841   238640.0        4.0
#
#                    deezer_title_artist                 spotify_title_artist  \
# 0  tennessee whiskey - chris stapleton  tennessee whiskey - chris stapleton
# 1           dance monkey - tones and i           dance monkey - tones and i
# 2        sweet caroline - neil diamond        sweet caroline - neil diamond
# 3    someone you loved - lewis capaldi    someone you loved - lewis capaldi
# 4                    creep - radiohead                    creep - radiohead
#
#                         l_title_artist d_year score
# 0  tennessee whiskey - chris stapleton   2015     0
# 1           dance monkey - tones and i   2019     0
# 2        sweet caroline - neil diamond   2017     0
# 3    someone you loved - lewis capaldi   2018     0
# 4                    creep - radiohead   1993     0
#
# [5 rows x 47 columns]

# %%
sample = get_score(sample)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
titles = sync[['title_artist', 'deezer_title_artist', 'spotify_title_artist', 'l_title_artist']]

# %%
titles.columns
# Out:
# Index(['title_artist', 'deezer_title_artist', 'spotify_title_artist',
#        'l_title_artist'],
#       dtype='object')

# %%
sync = sync[(sync['title_artist'] == sync['deezer_title_artist']) & (sync['title_artist'] == sync['spotify_title_artist'])& (sync['title_artist'] == sync['l_title_artist'])]

# %%
sync.drop(columns=['level_0', 'index'], inplace=True)

# %%
sync.columns
# Out:
# Index(['level_0', 'index', 'title', 'artist', 'year', 'explicit', 'styles',
#        'languages', 'title_artist', 'synced', 'd_id', 'd_song', 'd_isrc',
#        'd_release', 'd_explicit', 'd_bpm', 'd_artist', 'd_album_id', 'd_album',
#        'd_art', 'lyric_url', 'l_title', 'l_artist', 'l_album', 'l_writer',
#        'l_pub', 's_artist', 's_track', 's_uri', 's_dance', 's_energy', 's_key',
#        's_loudness', 's_mode', 's_speech', 's_acoustic', 's_inst', 's_live',
#        's_valence', 's_tempo', 's_duration', 's_time_sig',
#        'deezer_title_artist', 'spotify_title_artist', 'l_title_artist',
#        'd_year'],
#       dtype='object')

# %%
sync = sync[['title', 'artist', 'year', 'explicit', 'styles',
       'languages', 'title_artist', 'd_id', 'd_isrc',
       'd_release', 'd_album_id', 'd_album',
       'd_art', 'lyric_url','l_writer',
       'l_pub', 's_uri', 's_dance', 's_energy', 's_key',
       's_loudness', 's_mode', 's_speech', 's_acoustic', 's_inst', 's_live',
       's_valence', 's_tempo', 's_duration', 's_time_sig',
       'synced']]

# %%
sync
# Out:
#                    title           artist  year  explicit              styles  \
# 0      Tennessee Whiskey  Chris Stapleton  2015         0  Blues,Rock,Country
# 1           Dance Monkey      Tones and I  2019         0                 Pop
# 2         Sweet Caroline     Neil Diamond  1969         0                 Pop
# 3      Someone You Loved    Lewis Capaldi  2018         0                 Pop
# 4                  Creep        Radiohead  1992         1    Rock,Alternative
# ...                  ...              ...   ...       ...                 ...
# 10806      Odio Por Amor           Juanes  2008         0            Pop,Rock
# 10809   A Woman Like You        Lee Brice  2011         0             Country
# 10810        Buck Rogers           Feeder  2001         0    Rock,Alternative
# 10814      Beautiful War    Kings of Leon  2013         0    Alternative,Rock
# 10815     Midnight Blues       Gary Moore  1990         0          Blues,Rock
#
#              languages                         title_artist       d_id  \
# 0              English  tennessee whiskey - chris stapleton   98975170
# 1              English           dance monkey - tones and i  739870792
# 2              English        sweet caroline - neil diamond  145434430
# 3              English    someone you loved - lewis capaldi  582143242
# 4              English                    creep - radiohead  138547415
# ...                ...                                  ...        ...
# 10806  Spanish,English               odio por amor - juanes    2559824
# 10809          English         a woman like you - lee brice   75766206
# 10810          English                 buck rogers - feeder  131233178
# 10814          English        beautiful war - kings of leon   70584821
# 10815          English          midnight blues - gary moore    3133096
#
#              d_isrc   d_release  ...  s_mode s_speech s_acoustic    s_inst  \
# 0      USUM71418088  2015-05-04  ...     1.0   0.0298     0.2050  0.009600
# 1      QZES71982312  2019-08-29  ...     0.0   0.0924     0.6920  0.000104
# 2      USMC16991138  2017-03-31  ...     1.0   0.0274     0.6110  0.000109
# 3      DEUM71807062  2018-11-08  ...     1.0   0.0319     0.7510  0.000000
# 4      GBAYE9200070  1993-02-22  ...     1.0   0.0369     0.0102  0.000141
# ...             ...         ...  ...     ...      ...        ...       ...
# 10806  USUM70835975  2008-09-23  ...     0.0   0.0356     0.7060  0.033400
# 10809  USCRB1109727  2012-04-24  ...     0.0   0.0356     0.7060  0.033400
# 10810  GBBND0000727  1996-05-15  ...     0.0   0.0356     0.7060  0.033400
# 10814  USRC11300783  2013-09-20  ...     0.0   0.0356     0.7060  0.033400
# 10815  GBAAA9000066  1995-01-24  ...     0.0   0.0356     0.7060  0.033400
#
#        s_live s_valence  s_tempo  s_duration  s_time_sig  synced
# 0      0.0821     0.512   48.718    293293.0         4.0       1
# 1      0.1490     0.513   98.027    209438.0         4.0       1
# 2      0.2370     0.578   63.050    203573.0         4.0       1
# 3      0.1050     0.446  109.891    182161.0         4.0       1
# 4      0.1290     0.104   91.841    238640.0         4.0       1
# ...       ...       ...      ...         ...         ...     ...
# 10806  0.1290     0.259   70.828    172133.0         4.0       0
# 10809  0.1290     0.259   70.828    172133.0         4.0       0
# 10810  0.1290     0.259   70.828    172133.0         4.0       0
# 10814  0.1290     0.259   70.828    172133.0         4.0       0
# 10815  0.1290     0.259   70.828    172133.0         4.0       0
#
# [5530 rows x 31 columns]
